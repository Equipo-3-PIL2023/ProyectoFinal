-- %% [markdown]
-- # [SmartInvest_Pruebas]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [SmartInvest_Pruebas]    Script Date: 19/10/2023 10:05:11 ******/
CREATE DATABASE [SmartInvest_Pruebas]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SmartInvest_Pruebas', FILENAME = N'C:\D\MSSQL\data\SmartInvest_Pruebas.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SmartInvest_Pruebas_log', FILENAME = N'C:\L\MSSQL\logs\SmartInvest_Pruebas_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [SmartInvest_Pruebas] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [SmartInvest_Pruebas].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [SmartInvest_Pruebas] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET ARITHABORT OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET  DISABLE_BROKER 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET RECOVERY FULL 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET  MULTI_USER 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [SmartInvest_Pruebas] SET DB_CHAINING OFF 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [SmartInvest_Pruebas] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'SmartInvest_Pruebas', N'ON'
GO
ALTER DATABASE [SmartInvest_Pruebas] SET QUERY_STORE = ON
GO
ALTER DATABASE [SmartInvest_Pruebas] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [SmartInvest_Pruebas]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 19/10/2023 10:05:12 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Acciones]

-- %%
/****** Object:  Table [dbo].[Acciones]    Script Date: 19/10/2023 10:05:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Acciones](
	[idAccion] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[simbolo] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Acciones] PRIMARY KEY CLUSTERED 
(
	[idAccion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cuenta]

-- %%
/****** Object:  Table [dbo].[Cuenta]    Script Date: 19/10/2023 10:05:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cuenta](
	[idCuenta] [int] IDENTITY(1,1) NOT NULL,
	[idUsuario] [int] NOT NULL,
	[saldo] [decimal](18, 2) NOT NULL,
 CONSTRAINT [PK_Cuenta_1] PRIMARY KEY CLUSTERED 
(
	[idCuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Transaccion]

-- %%
/****** Object:  Table [dbo].[Transaccion]    Script Date: 19/10/2023 10:05:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Transaccion](
	[idTransaccion] [int] IDENTITY(1,1) NOT NULL,
	[idAccion] [int] NOT NULL,
	[idCuenta] [int] NOT NULL,
	[fecha] [datetime] NOT NULL,
	[precioCompra] [decimal](18, 2) NOT NULL,
	[cantidad] [int] NOT NULL,
	[comision] [decimal](18, 2) NOT NULL,
 CONSTRAINT [PK_Transaccion] PRIMARY KEY CLUSTERED 
(
	[idTransaccion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 19/10/2023 10:05:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[idUsuario] [int] IDENTITY(1,1) NOT NULL,
	[password] [varchar](150) NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[apellido] [varchar](50) NOT NULL,
	[correo] [varchar](50) NOT NULL,
	[dni] [int] NOT NULL,
	[tipoDni] [varchar](50) NOT NULL,
	[telefono] [varchar](50) NOT NULL,
	[codigoPostal] [int] NOT NULL,
	[ciudad] [varchar](50) NOT NULL,
	[provincia] [varchar](50) NOT NULL,
	[pais] [varchar](50) NOT NULL,
	[fechaNacimiento] [date] NOT NULL,
 CONSTRAINT [PK_Usuario] PRIMARY KEY CLUSTERED 
(
	[idUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Acciones]

-- %%
SET IDENTITY_INSERT [dbo].[Acciones] ON 
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (4, N'Agrometal', N'AGRO')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (5, N'Aluar', N'ALUA')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (6, N'Autopistas del Sol', N'AUSO')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (7, N'Bbva', N'BBAR')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (8, N'Banco Hipotecario', N'BHIP')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (9, N'Banco Macro', N'BMA')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (10, N'Boldt', N'BOLT')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (11, N'Banco Santander Rio', N'BRIO')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (12, N'Bolsas Y Mercados Argentinos S.A.', N'BYMA')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (13, N'Carlos Casado', N'CADO')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (14, N'Capex', N'CAPX')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (15, N'Carboclor S.A.', N'CARC')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (16, N'Endesa Costanera', N'CECO2')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (17, N'Celulosa', N'CELU')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (18, N'Central Puerto Sa', N'CEPU')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (19, N'Camuzzi Gas Pampeana', N'CGPA2')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (20, N'Sociedad Comercial del Plata', N'COME')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (21, N'WARRANT CRESUD S.A.C.I.F. VTO 08/03/26', N'CRE3W')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (22, N'Cresud', N'CRES')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (23, N'Consultatio', N'CTIO')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (24, N'Cablevisión Holding S.A.', N'CVH')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (25, N'Distribuidora de Gas Cuyana', N'DGCU2')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (26, N'Suscripción Preferente Domec S.A.', N'DOME')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (27, N'Dycasa', N'DYCA')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (28, N'EDESAL HOLDING S.A. 1 VOTO $ ESC.', N'EDLH')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (29, N'Edenor', N'EDN')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (30, N'EDESA HOLDING S.A.', N'EDSH')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (31, N'EMP.DISTRIB.LA PLATA(EDELAP)-ORD.B 1 V', N'ELAP')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (32, N'ELECTROMAC', N'EMAC')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (33, N'Bodegas Esmeralda', N'ESME')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (34, N'Ferrum', N'FERR')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (35, N'Fiplasto', N'FIPL')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (36, N'B-Gaming S.A.', N'GAMI')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (37, N'Garovaglio y Zorraquin', N'GARO')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (38, N'Gas Natural BAN', N'GBAN')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (39, N'Gcdi S.A. Acciones Ord Esc.', N'GCDI')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (40, N'Grupo Clarín', N'GCLA')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (41, N'Grupo Financiero Galicia S.A', N'GGAL')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (42, N'Grimoldi', N'GRIM')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (43, N'Holcim (Argentina) Ords. 1 Voto', N'HARG')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (44, N'Havanna Holding S.A.', N'HAVA')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (45, N'Hulytego S.A.', N'HULI')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (46, N'Insumos Agroquímicos', N'INAG')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (47, N'Compania Introductora de Bs As', N'INTR')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (48, N'Inversora Juramento S.A.', N'INVJ')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (49, N'Alto Palermo', N'IRCP')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (50, N'WARRANT INVERSIONES Y REPRESENTACIONES S.A.', N'IRS2W')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (51, N'Irsa', N'IRSA')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (52, N'Ledesma', N'LEDE')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (53, N'Loma Negra Compañia Industrial Argentina Sa', N'LOMA')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (54, N'Longvie', N'LONG')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (55, N'Metrogas', N'METR')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (56, N'Mirgor', N'MIRG')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (57, N'Molinos Agro S.A.', N'MOLA')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (58, N'Molinos Agro S.A 5V $ ESC.', N'MOLA5')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (59, N'Molinos Río De La Plata', N'MOLI')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (60, N'Molinos Río de la Plata 5 Votos', N'MOLI5')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (61, N'Morixe Hermanos', N'MORI')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (62, N'Matba Rofex S.A.', N'MTR')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (63, N'Grupo Concesionario del Oeste', N'OEST')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (64, N'Pampa Energía', N'PAMP')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (65, N'Imp. y Exportadora de la Patagonia', N'PATA')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (66, N'Phoenix Global Resources Plc', N'PGR')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (67, N'Polledo', N'POLL')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (68, N'García Regera', N'REGE')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (69, N'Laboratorios Richmond S.A.C.I.F.', N'RICH')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (70, N'Rigolleau', N'RIGO')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (71, N'San Miguel', N'SAMI')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (72, N'Molinos Juan Semino', N'SEMI')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (73, N'Grupo Supervielle S.A.', N'SUPV')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (74, N'Telecom Argentina', N'TECO2')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (75, N'Transportadora Gas del Norte', N'TGNO4')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (76, N'Transportadora Gas del Sur', N'TGSU2')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (77, N'Transener', N'TRAN')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (78, N'Ternium Argentina Sa', N'TXAR')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (79, N'Banco de Valores S.A.', N'VALO')
INSERT [dbo].[Acciones] ([idAccion], [nombre], [simbolo]) VALUES (80, N'YPF', N'YPFD')
SET IDENTITY_INSERT [dbo].[Acciones] OFF
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
SET IDENTITY_INSERT [dbo].[Usuario] ON 
INSERT [dbo].[Usuario] ([idUsuario], [password], [nombre], [apellido], [correo], [dni], [tipoDni], [telefono], [codigoPostal], [ciudad], [provincia], [pais], [fechaNacimiento]) VALUES (29, N'FQGEX1ScAs4Zjn2P3MogyQ==', N'Ignacio', N'Diaz', N'ignacio_dior@hotmail.com', 41345567, N'DNI', N'351345678', 5010, N'Córdoba', N'Córdoba', N'Argentina', CAST(N'1998-10-16' AS Date))
INSERT [dbo].[Usuario] ([idUsuario], [password], [nombre], [apellido], [correo], [dni], [tipoDni], [telefono], [codigoPostal], [ciudad], [provincia], [pais], [fechaNacimiento]) VALUES (30, N'cd0auJ/4+aKOPbnnOFJvmQ==', N'Pablo', N'Gonzalez', N'pablo@mail.com', 34545623, N'DNI', N'351345421', 5030, N'Córdoba', N'Córdoba', N'Argentina', CAST(N'1989-10-16' AS Date))
SET IDENTITY_INSERT [dbo].[Usuario] OFF
GO

-- %% [markdown]
-- # [FK_Cuenta_Usuario]

-- %%
ALTER TABLE [dbo].[Cuenta]  WITH CHECK ADD  CONSTRAINT [FK_Cuenta_Usuario] FOREIGN KEY([idUsuario])
REFERENCES [dbo].[Usuario] ([idUsuario])
GO
ALTER TABLE [dbo].[Cuenta] CHECK CONSTRAINT [FK_Cuenta_Usuario]
GO

-- %% [markdown]
-- # [FK_Transaccion_Acciones]

-- %%
ALTER TABLE [dbo].[Transaccion]  WITH CHECK ADD  CONSTRAINT [FK_Transaccion_Acciones] FOREIGN KEY([idAccion])
REFERENCES [dbo].[Acciones] ([idAccion])
GO
ALTER TABLE [dbo].[Transaccion] CHECK CONSTRAINT [FK_Transaccion_Acciones]
GO

-- %% [markdown]
-- # [FK_Transaccion_Cuenta1]

-- %%
ALTER TABLE [dbo].[Transaccion]  WITH CHECK ADD  CONSTRAINT [FK_Transaccion_Cuenta1] FOREIGN KEY([idCuenta])
REFERENCES [dbo].[Cuenta] ([idCuenta])
GO
ALTER TABLE [dbo].[Transaccion] CHECK CONSTRAINT [FK_Transaccion_Cuenta1]
GO

-- %% [markdown]
-- # [SmartInvest_Pruebas]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [SmartInvest_Pruebas] SET  READ_WRITE 
GO
